# %% [markdown]
# # Bird Classifier using Transfer Learning from MobileNetv2
#
# ## Notebook Abstract:
#
# This model is a demonstration on using Transfer Learning to build an accurate model quickly.
#
# It will build a model by loading in the dataset and performing image augmentation, running it through the MobileNetV2 model without the top, and using 4 ending dense layers to output a 450 class softmax for each species of bird in the dataset.
#
# The training will be done in 3 rounds of fitting:
# * Each round will run for 10 epochs.
# * Each round will subsequently increase the number of trainable layers at the end of the Mobile Net base model.
# * Each round will shrink the learning rate by a scaling factor.
#
# Lets start!
#
# <img src="https://i.pinimg.com/originals/0c/6a/f2/0c6af2ed796422de38d7467cff88bf43.gif" width="400" align="center">

# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import Sequential
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, recall_score
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Set Hyperparameters

# %%
FILEPATH = '../input/100-bird-species/' # filepath for data
BATCH_SIZE = 64 # keras training batch size
IMAGE_SIZE = (224, 224) # size of images in dataset (keras will resize)

ROUND_1_TRAINABLE_LAYERS = 38 # layers at end of the mobile_net base model to have trainable parameters
ROUND_1_EPOCHS = 5

LEARNING_RATE = 0.0001

MODEL_CHECKPOINT_FILEPATH = './Bird-Classifier-Model-Checkpoint.ckpt'

SEED = 6278 # random seed for repeatability of notebook

# %% [markdown]
# ## Load Datasets with *image_dataset_from_directory*

# %%
# Training Dataset
train = image_dataset_from_directory(directory = FILEPATH + 'train/',
                                     shuffle = True,
                                     labels='inferred',
                                     label_mode='categorical',
                                     batch_size = BATCH_SIZE,
                                     image_size = IMAGE_SIZE,
                                     seed = SEED)

# Validation Dataset
valid = image_dataset_from_directory(directory = FILEPATH + 'valid/',
                                     shuffle = True,
                                     labels='inferred',
                                     label_mode='categorical',
                                     batch_size = BATCH_SIZE,
                                     image_size = IMAGE_SIZE,
                                     seed = SEED)

# Test Dataset
test = image_dataset_from_directory(directory = FILEPATH + 'test/',
                                     shuffle = True,
                                     labels='inferred',
                                     label_mode='categorical',
                                     batch_size = BATCH_SIZE,
                                     image_size = IMAGE_SIZE,
                                     seed = SEED)
# Out:
# Found 70626 files belonging to 450 classes.
# 2022-12-19 08:28:42.090505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:42.261733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:42.262683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:42.264801: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 08:28:42.265086: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:42.265764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:42.266426: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:44.596954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:44.598220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:44.599238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 08:28:44.600147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 2250 files belonging to 450 classes.
# Found 2250 files belonging to 450 classes.

# %% [markdown]
# ## Visualize Data Samples

# %%
class_names = train.class_names

plt.figure(figsize=(18, 10))

for images, labels in train.take(1):
    for i in range(15):
        ax = plt.subplot(3, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")
# Out:
# 2022-12-19 08:29:04.212938: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# # Data Augmentation

# %%
def data_augmentor(h_flip=True, v_flip=False, rotate=True,):
    
    augmentor = Sequential() # Create returned Sequential class.
    augmentor.add(layers.Rescaling(1./255)) # Rescale image values from 0 - 255 to 0 - 1.

    # Based on function arguments: perform random flipping
    if h_flip and v_flip:
        augmentor.add(layers.RandomFlip('horizontal_and_vertical'))
    elif h_flip:
        augmentor.add(layers.RandomFlip('horizontal'))
    elif v_flip:
        augmentor.add(layers.RandomFlip('vertical'))

    # Based on function arguments: perform random rotation    
    if rotate:
        augmentor.add(layers.RandomRotation(0.2))
    
    return augmentor

# %%
augmentor1 = data_augmentor(h_flip = True, v_flip = True, rotate=False)
augmentor2 = data_augmentor(h_flip = False, v_flip = False, rotate=True)
augmentor3 = data_augmentor(h_flip = True, v_flip = False, rotate=True)

augs = [augmentor1, augmentor2, augmentor3]

details = ['H and V Flip',
           'Rotate',
           'H Flip and Rotate']

plt.figure(figsize=(20, 8))
for images, labels in train.take(1):
    for i, aug in enumerate(augs):
        img = images[i]
        for j in range(8):
            ax = plt.subplot(3, 8, (i*8 + j + 1))
            img_augmented = aug(tf.expand_dims(img, 0))
            plt.imshow(img_augmented[0])
            plt.axis('off')
            ax.set_title(details[i])
            
plt.suptitle('Different Augmentations Demonstration', fontsize=20);

# %% [markdown]
# # Import MobileNetV2 Base Model

# %%
IMAGE_SHAPE = IMAGE_SIZE + (3,)

mobile_base = MobileNetV2(input_shape = IMAGE_SHAPE,
                          include_top = False,
                          weights = 'imagenet')

mn_layers = len(mobile_base.layers)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
mobile_base.trainable = True

print('Setting the last {} layers in the Mobile Net Base Model to trainable!\n'.format(ROUND_1_TRAINABLE_LAYERS))

for mn_layer in mobile_base.layers[:-ROUND_1_TRAINABLE_LAYERS]:
    mn_layer.trainable = False
    
trainableParams = np.sum([np.prod(v.get_shape()) for v in mobile_base.trainable_weights])
nonTrainableParams = np.sum([np.prod(v.get_shape()) for v in mobile_base.non_trainable_weights])
totalParams = trainableParams + nonTrainableParams

print('The number of trainable parameters in the Mobile Net V2 Base Model is {}.'.format(trainableParams))
print('The number of non-trainable parameters in the Mobile Net V2 Base Model is {}.'.format(nonTrainableParams))
print('The total number of parameters is {}.'.format(totalParams))
# Out:
# Setting the last 38 layers in the Mobile Net Base Model to trainable!
#
# The number of trainable parameters in the Mobile Net V2 Base Model is 1681344.
# The number of non-trainable parameters in the Mobile Net V2 Base Model is 576640.
# The total number of parameters is 2257984.

# %% [markdown]
# # Build Model
# ## Augmentor &rarr; Mobile Net V2 Base &rarr; 3 Dense Layers resulting in Softmax Output

# %%
# start model with input shape equal to image shape
inputs = tf.keras.Input(shape = IMAGE_SHAPE)
# apply h-flip and rotation data augmentation
x = augmentor3(inputs)
# apply through mobile net v2 base
x = mobile_base(x)
# global average pool to collapse to 1D
x = layers.GlobalAveragePooling2D()(x) 
# normalize layer
x = layers.BatchNormalization()(x)
# apply relu activation
x = layers.ReLU()(x)
# include dropout with probability of 0.2 to avoid overfitting
x = layers.Dropout(0.25)(x)
# densely connected layer with 2000
x = layers.Dense(1500)(x) 
# normalize layer
x = layers.BatchNormalization()(x)
# apply relu activation
x = layers.ReLU()(x)
# include dropout with probability of 0.2 to avoid overfitting
x = layers.Dropout(0.25)(x)
# densely connected output layer with same number of output classes
x = layers.Dense(1200)(x) 
# normalize layer
x = layers.BatchNormalization()(x)
# apply relu activation
x = layers.ReLU()(x)
# include dropout with probability of 0.2 to avoid overfitting
x = layers.Dropout(0.25)(x)
# densely connected output layer with same number of output classes
x = layers.Dense(900)(x) 
# normalize layer
x = layers.BatchNormalization()(x)
# apply relu activation
x = layers.ReLU()(x)
# include dropout with probability of 0.2 to avoid overfitting
x = layers.Dropout(0.25)(x)
# densely connected output layer with same number of output classes
outputs = layers.Dense(450, activation='softmax')(x) 
        
model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 224, 224, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1280)              5120
# _________________________________________________________________
# re_lu (ReLU)                 (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 1500)              1921500
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1500)              6000
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 1500)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1500)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1200)              1801200
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1200)              4800
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 1200)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 900)               1080900
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 900)               3600
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 900)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 900)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 450)               405450
# =================================================================
# Total params: 7,486,554
# Trainable params: 6,900,154
# Non-trainable params: 586,400
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = LEARNING_RATE)
#optimizer = tf.keras.optimizers.SGD(learning_rate = LEARNING_RATE,momentum=0)
#optimizer = tf.keras.optimizers.RMSprop(learning_rate = LEARNING_RATE)

loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False)

model_checkpoint = ModelCheckpoint(MODEL_CHECKPOINT_FILEPATH,
                                   monitor='val_accuracy',
                                   save_best_only=True,
                                   save_weights_only=True,
                                   verbose=1,
                                   mode = 'max')

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

callbacks = [model_checkpoint,early_stopping]

model.compile(optimizer = optimizer,
              loss = loss,
              metrics=['accuracy'])

# %%
history = model.fit(train, 
                    validation_data=valid, 
                    epochs=ROUND_1_EPOCHS, 
                    callbacks = callbacks)
# Out:
# Epoch 1/5
# 2022-12-19 08:30:30.262088: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 1104/1104 [==============================] - 247s 213ms/step - loss: 4.5744 - accuracy: 0.1757 - val_loss: 2.2256 - val_accuracy: 0.5347
#
# Epoch 00001: val_accuracy improved from -inf to 0.53467, saving model to ./Bird-Classifier-Model-Checkpoint.ckpt
# Epoch 2/5
# 1104/1104 [==============================] - 123s 111ms/step - loss: 2.0275 - accuracy: 0.5616 - val_loss: 0.8764 - val_accuracy: 0.7924
#
# Epoch 00002: val_accuracy improved from 0.53467 to 0.79244, saving model to ./Bird-Classifier-Model-Checkpoint.ckpt
# Epoch 3/5
# 1104/1104 [==============================] - 119s 107ms/step - loss: 1.2044 - accuracy: 0.7156 - val_loss: 0.5167 - val_accuracy: 0.8729
#
# Epoch 00003: val_accuracy improved from 0.79244 to 0.87289, saving model to ./Bird-Classifier-Model-Checkpoint.ckpt
# Epoch 4/5
# 1104/1104 [==============================] - 124s 111ms/step - loss: 0.8649 - accuracy: 0.7851 - val_loss: 0.4039 - val_accuracy: 0.8956
#
# Epoch 00004: val_accuracy improved from 0.87289 to 0.89556, saving model to ./Bird-Classifier-Model-Checkpoint.ckpt
# Epoch 5/5
# 1104/1104 [==============================] - 125s 113ms/step - loss: 0.6890 - accuracy: 0.8209 - val_loss: 0.2935 - val_accuracy: 0.9124
#
# Epoch 00005: val_accuracy improved from 0.89556 to 0.91244, saving model to ./Bird-Classifier-Model-Checkpoint.ckpt

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(16,6))
title_fontsize = 16
axis_fontsize = 12

total_epochs = ROUND_1_EPOCHS

ax1.plot(range(1, total_epochs + 1), history.history['loss'], marker='o', label='Training loss')
ax1.plot(range(1, total_epochs + 1), history.history['val_loss'], marker='o', label='Validation Loss')
ax1.legend()
ax1.set_xticks(range(1, total_epochs + 1))
ax1.set_title('Loss', fontsize=title_fontsize)
ax1.set_xlabel('Epoch', fontsize=axis_fontsize)

ax2.plot(range(1, total_epochs + 1), history.history['accuracy'], marker='o', label='Training Accuracy')
ax2.plot(range(1, total_epochs + 1), history.history['val_accuracy'], marker='o', label='Validation Accuracy')
ax2.legend()
ax2.set_xticks(range(1, total_epochs + 1))
ax2.set_title('Accuracy', fontsize=title_fontsize)
ax2.set_xlabel('Epoch', fontsize=axis_fontsize);

# %% [markdown]
# # Evaluate Model Accuracy on Test Data

# %%
model = load_model('/kaggle/working/Bird-Classifier-Model-Checkpoint.ckpt/saved_model.pb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23/1698734607.py in <module>
# ----> 1 model = load_model('/kaggle/working/Bird-Classifier-Model-Checkpoint.ckpt/saved_model.pb')
#
# NameError: name 'load_model' is not defined

# %%
model.load_weights(MODEL_CHECKPOINT_FILEPATH)

test_loss, test_accuracy = model.evaluate(test)

print('\n\033[1m' + 'The model had an accuracy score of {}%!!'.format(round(100*test_accuracy,1)) + '\033[0m')
# Out:
# 36/36 [==============================] - 9s 183ms/step - loss: 0.2704 - accuracy: 0.9280
#
# The model had an accuracy score of 92.8%!!

# %%
plt.figure(figsize=(20, 18))

for images, labels in test.take(1):
    guesses = np.argmax(model.predict(images), axis=1)
    for i in range(25):
        ax = plt.subplot(5, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        if guesses[i] == np.argmax(labels[i]):
            color = 'tab:green'
        else:
            color = 'tab:red'
        plt.title('Actual Label: {}\nPredicted Label: {}'.format(
                            class_names[np.argmax(labels[i])], class_names[guesses[i]]),
                 color = color)
        plt.axis("off")

# %% [markdown]
# # Predict radom image

# %%
#plt.figure(figsize=(20, 18))

k = random.randint (1, len(test))

for images, labels in test.take(1):
    guesses = np.argmax(model.predict(images), axis=1)
    for i in range(1):
        ax = plt.subplot(1, 1, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        if guesses[i] == np.argmax(labels[i]):
            color = 'tab:green'
        else:
            color = 'tab:red'
        plt.title('Actual Label: {}\nPredicted Label: {}'.format(
                            class_names[np.argmax(labels[i])], class_names[guesses[i]]),
                 color = color)
        plt.axis("off")

# %%
CLASSES = len (class_names)
print(CLASSES)
# Out:
# 450

# %%
directory = FILEPATH + 'test/'
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
test_generator = test_datagen.flow_from_directory(
            directory,
            target_size=(224,224),
            batch_size=1,
            class_mode='categorical',
            shuffle=False
          )
# Out:
# Found 2250 images belonging to 450 classes.

# %%
img_test = []
for i in sorted (os.listdir(directory)):
  bird = os.path.join(directory, i)
  for j in sorted(os.listdir(bird)):
    img_test.append (os.path.join(bird, j))

# %%
true_labels = []
pred_labels = []
for k in range (len(test_generator)):
  images = img_test[k]
  true_label = np.argmax(test_generator[k][1])
  pred_label = np.argmax (model.predict (test_generator[k][0]))
  true_labels.append (true_label)
  pred_labels.append (pred_label)

# %%
precision = precision_score(true_labels, pred_labels, average='macro')
precision
# Out:
# 0.9414038800705468

# %%
recall = recall_score(true_labels, pred_labels, average='macro')
recall
# Out:
# 0.9257777777777778

# %%
print ('Accuracy', accuracy_score(true_labels, pred_labels))
print ('F1-score:', precision_score(true_labels, pred_labels, average='macro'))
# Out:
# Accuracy 0.9257777777777778
# F1-score: 0.9414038800705468

# %%
def precision(matrix, n):
    avg_precise = 0
    for i in range(n):
        tp = matrix[i][i]
        pred = np.sum(matrix[:, i])
        if (pred != 0):
            avg_precise += tp / pred

    return avg_precise / n


def recall(matrix, n):
    avg_recall = 0
    for i in range(n):
        tp = matrix[i][i]
        true = np.sum(matrix[i,:])
        avg_recall += tp / true

    return avg_recall / n


def f1_score(precision, recall):
    return (2 * precision * recall) / (precision + recall)

# %%
from sklearn import metrics

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, pred_labels)

# %%
confusion_matrix
# Out:
# array([[5, 0, 0, ..., 0, 0, 0],
#        [0, 2, 0, ..., 0, 0, 0],
#        [0, 0, 5, ..., 0, 0, 0],
#        ...,
#        [0, 0, 0, ..., 5, 0, 0],
#        [0, 0, 0, ..., 0, 5, 0],
#        [0, 0, 0, ..., 0, 0, 4]])

# %%
r = recall(confusion_matrix,450)

# %%
r
# Out:
# 0.9257777777777789

# %%
p = precision(confusion_matrix,450)

# %%
p
# Out:
# 0.9414038800705463

# %%
print(f1_score(p, r))
# Out:
# 0.9335254429260093

# %%
def accuracy (y_true, y_pred):
  sum = 0
  n = len(y_true)
  for i in range (n):
    sum+=int (y_true[i]==y_pred[i])
  return sum/n

# %%
accuracy (true_labels, pred_labels)
# Out:
# 0.9257777777777778

# %%
train_dir = FILEPATH + 'train/'
class_name = sorted (os.listdir(train_dir))

# %%
dict_bird_name = {}
for i in range (CLASSES):
  dict_bird_name[i] = class_name[i]

# %%
target_names = list (dict_bird_name.values())
print(classification_report(true_labels, pred_labels, target_names=target_names))
# Out:
#                                precision    recall  f1-score   support
#
#               ABBOTTS BABBLER       1.00      1.00      1.00         5
#                 ABBOTTS BOOBY       1.00      0.40      0.57         5
#    ABYSSINIAN GROUND HORNBILL       1.00      1.00      1.00         5
#         AFRICAN CROWNED CRANE       1.00      1.00      1.00         5
#        AFRICAN EMERALD CUCKOO       1.00      1.00      1.00         5
#             AFRICAN FIREFINCH       1.00      1.00      1.00         5
#        AFRICAN OYSTER CATCHER       1.00      1.00      1.00         5
#         AFRICAN PIED HORNBILL       1.00      0.60      0.75         5
#                     ALBATROSS       0.83      1.00      0.91         5
#                ALBERTS TOWHEE       1.00      1.00      1.00         5
#          ALEXANDRINE PARAKEET       1.00      1.00      1.00         5
#                 ALPINE CHOUGH       1.00      1.00      1.00         5
#         ALTAMIRA YELLOWTHROAT       1.00      0.60      0.75         5
#               AMERICAN AVOCET       0.83      1.00      0.91         5
#       YELLOW HEADED BLACKBIRD       1.00      0.80      0.89         5
#
#                      accuracy                           0.93      2250
#                     macro avg       0.94      0.93      0.92      2250
#                  weighted avg       0.94      0.93      0.92      2250

# %%
for i in range(CLASSES):
    score_sum = 0
    for j in range(5):
        score_sum += int(true_labels[i*5+j] == pred_labels[i*5+j])
    if score_sum == 5:
        print('\033[92m' + '{}: {} / 5'.format(dict_bird_name[i], score_sum))
    else:
        print('\033[91m' + '{}: {} / 5'.format(dict_bird_name[i], score_sum))
# Out:
# ABBOTTS BABBLER: 5 / 5
# ABBOTTS BOOBY: 2 / 5
# ABYSSINIAN GROUND HORNBILL: 5 / 5
# AFRICAN CROWNED CRANE: 5 / 5
# AFRICAN EMERALD CUCKOO: 5 / 5
# AFRICAN FIREFINCH: 5 / 5
# AFRICAN OYSTER CATCHER: 5 / 5
# AFRICAN PIED HORNBILL: 3 / 5
# ALBATROSS: 5 / 5
# ALBERTS TOWHEE: 5 / 5
# ALEXANDRINE PARAKEET: 5 / 5
# ALPINE CHOUGH: 5 / 5
# ALTAMIRA YELLOWTHROAT: 3 / 5
# AMERICAN AVOCET: 5 / 5
# AMERICAN BITTERN: 5 / 5
# AMERICAN COOT: 5 / 5
# AMERICAN FLAMINGO: 5 / 5
# AMERICAN GOLDFINCH: 5 / 5
# AMERICAN KESTREL: 5 / 5
# AMERICAN PIPIT: 5 / 5
# AMERICAN REDSTART: 4 / 5
# AMERICAN WIGEON: 5 / 5
# AMETHYST WOODSTAR: 4 / 5
# ANDEAN GOOSE: 5 / 5
# ANDEAN LAPWING: 5 / 5
# ANDEAN SISKIN: 5 / 5
# ANHINGA: 5 / 5
# ANIANIAU: 4 / 5
# ANNAS HUMMINGBIRD: 5 / 5
# ANTBIRD: 5 / 5
# ANTILLEAN EUPHONIA: 3 / 5
# APAPANE: 5 / 5
# APOSTLEBIRD: 5 / 5
# ARARIPE MANAKIN: 5 / 5
# ASHY STORM PETREL: 1 / 5
# ASHY THRUSHBIRD: 5 / 5
# ASIAN CRESTED IBIS: 5 / 5
# ASIAN DOLLARD BIRD: 5 / 5
# AUCKLAND SHAQ: 2 / 5
# AUSTRAL CANASTERO: 3 / 5
# AUSTRALASIAN FIGBIRD: 5 / 5
# AVADAVAT: 3 / 5
# AZARAS SPINETAIL: 4 / 5
# AZURE BREASTED PITTA: 5 / 5
# AZURE JAY: 4 / 5
# AZURE TANAGER: 4 / 5
# AZURE TIT: 5 / 5
# BAIKAL TEAL: 5 / 5
# BALD EAGLE: 4 / 5
# BALD IBIS: 5 / 5
# BALI STARLING: 5 / 5
# BALTIMORE ORIOLE: 5 / 5
# BANANAQUIT: 4 / 5
# BAND TAILED GUAN: 4 / 5
# BANDED BROADBILL: 5 / 5
# BANDED PITA: 5 / 5
# BANDED STILT: 4 / 5
# BAR-TAILED GODWIT: 5 / 5
# BARN OWL: 5 / 5
# BARN SWALLOW: 5 / 5
# BARRED PUFFBIRD: 5 / 5
# BARROWS GOLDENEYE: 5 / 5
# BAY-BREASTED WARBLER: 5 / 5
# BEARDED BARBET: 5 / 5
# BEARDED BELLBIRD: 5 / 5
# BEARDED REEDLING: 5 / 5
# BELTED KINGFISHER: 5 / 5
# BIRD OF PARADISE: 5 / 5
# BLACK & YELLOW BROADBILL: 5 / 5
# BLACK BAZA: 3 / 5
# BLACK COCKATO: 5 / 5
# BLACK FRANCOLIN: 4 / 5
# BLACK SKIMMER: 5 / 5
# BLACK SWAN: 5 / 5
# BLACK TAIL CRAKE: 4 / 5
# BLACK THROATED BUSHTIT: 5 / 5
# BLACK THROATED WARBLER: 5 / 5
# BLACK VENTED SHEARWATER: 3 / 5
# BLACK VULTURE: 5 / 5
# BLACK-CAPPED CHICKADEE: 5 / 5
# BLACK-NECKED GREBE: 5 / 5
# BLACK-THROATED SPARROW: 5 / 5
# BLACKBURNIAM WARBLER: 5 / 5
# BLONDE CRESTED WOODPECKER: 5 / 5
# BLOOD PHEASANT: 5 / 5
# BLUE COAU: 5 / 5
# BLUE DACNIS: 1 / 5
# BLUE GROUSE: 4 / 5
# BLUE HERON: 5 / 5
# BLUE MALKOHA: 4 / 5
# BLUE THROATED TOUCANET: 5 / 5
# BOBOLINK: 5 / 5
# BORNEAN BRISTLEHEAD: 5 / 5
# BORNEAN LEAFBIRD: 3 / 5
# BORNEAN PHEASANT: 5 / 5
# BRANDT CORMARANT: 5 / 5
# BREWERS BLACKBIRD: 2 / 5
# BROWN CREPPER: 3 / 5
# BROWN NOODY: 5 / 5
# BROWN THRASHER: 5 / 5
# BUFFLEHEAD: 4 / 5
# BULWERS PHEASANT: 5 / 5
# BURCHELLS COURSER: 5 / 5
# BUSH TURKEY: 4 / 5
# CAATINGA CACHOLOTE: 5 / 5
# CACTUS WREN: 5 / 5
# CALIFORNIA CONDOR: 5 / 5
# CALIFORNIA GULL: 5 / 5
# CALIFORNIA QUAIL: 5 / 5
# CAMPO FLICKER: 5 / 5
# CANARY: 5 / 5
# CAPE GLOSSY STARLING: 5 / 5
# CAPE LONGCLAW: 5 / 5
# CAPE MAY WARBLER: 4 / 5
# CAPE ROCK THRUSH: 5 / 5
# CAPPED HERON: 5 / 5
# CAPUCHINBIRD: 5 / 5
# CARMINE BEE-EATER: 5 / 5
# CASPIAN TERN: 5 / 5
# CASSOWARY: 5 / 5
# CEDAR WAXWING: 5 / 5
# CERULEAN WARBLER: 4 / 5
# CHARA DE COLLAR: 5 / 5
# CHATTERING LORY: 5 / 5
# CHESTNET BELLIED EUPHONIA: 5 / 5
# CHINESE BAMBOO PARTRIDGE: 5 / 5
# CHINESE POND HERON: 3 / 5
# CHIPPING SPARROW: 3 / 5
# CHUCAO TAPACULO: 5 / 5
# CHUKAR PARTRIDGE: 5 / 5
# CINNAMON ATTILA: 5 / 5
# CINNAMON FLYCATCHER: 4 / 5
# CINNAMON TEAL: 5 / 5
# CLARKS NUTCRACKER: 5 / 5
# COCK OF THE  ROCK: 5 / 5
# COCKATOO: 5 / 5
# COLLARED ARACARI: 5 / 5
# COMMON FIRECREST: 5 / 5
# COMMON GRACKLE: 5 / 5
# COMMON HOUSE MARTIN: 5 / 5
# COMMON IORA: 5 / 5
# COMMON LOON: 5 / 5
# COMMON POORWILL: 5 / 5
# COMMON STARLING: 5 / 5
# COPPERY TAILED COUCAL: 5 / 5
# CRAB PLOVER: 5 / 5
# CRANE HAWK: 5 / 5
# CREAM COLORED WOODPECKER: 5 / 5
# CRESTED AUKLET: 5 / 5
# CRESTED CARACARA: 5 / 5
# CRESTED COUA: 3 / 5
# CRESTED FIREBACK: 5 / 5
# CRESTED KINGFISHER: 5 / 5
# CRESTED NUTHATCH: 5 / 5
# CRESTED OROPENDOLA: 4 / 5
# CRESTED SHRIKETIT: 4 / 5
# CRIMSON CHAT: 5 / 5
# CRIMSON SUNBIRD: 5 / 5
# CROW: 5 / 5
# CROWNED PIGEON: 2 / 5
# CUBAN TODY: 5 / 5
# CUBAN TROGON: 5 / 5
# CURL CRESTED ARACURI: 5 / 5
# D-ARNAUDS BARBET: 5 / 5
# DALMATIAN PELICAN: 5 / 5
# DARJEELING WOODPECKER: 4 / 5
# DARK EYED JUNCO: 5 / 5
# DARWINS FLYCATCHER: 1 / 5
# DAURIAN REDSTART: 3 / 5
# DEMOISELLE CRANE: 5 / 5
# DOUBLE BARRED FINCH: 5 / 5
# DOUBLE BRESTED CORMARANT: 4 / 5
# DOUBLE EYED FIG PARROT: 5 / 5
# DOWNY WOODPECKER: 5 / 5
# DUSKY LORY: 5 / 5
# DUSKY ROBIN: 4 / 5
# EARED PITA: 5 / 5
# EASTERN BLUEBIRD: 5 / 5
# EASTERN BLUEBONNET: 4 / 5
# EASTERN GOLDEN WEAVER: 4 / 5
# EASTERN MEADOWLARK: 5 / 5
# EASTERN ROSELLA: 5 / 5
# EASTERN TOWEE: 5 / 5
# EASTERN WIP POOR WILL: 4 / 5
# ECUADORIAN HILLSTAR: 5 / 5
# EGYPTIAN GOOSE: 5 / 5
# ELEGANT TROGON: 4 / 5
# ELLIOTS  PHEASANT: 4 / 5
# EMERALD TANAGER: 4 / 5
# EMPEROR PENGUIN: 5 / 5
# EMU: 5 / 5
# ENGGANO MYNA: 5 / 5
# EURASIAN BULLFINCH: 3 / 5
# EURASIAN GOLDEN ORIOLE: 5 / 5
# EURASIAN MAGPIE: 5 / 5
# EUROPEAN GOLDFINCH: 4 / 5
# EUROPEAN TURTLE DOVE: 5 / 5
# EVENING GROSBEAK: 5 / 5
# FAIRY BLUEBIRD: 5 / 5
# FAIRY PENGUIN: 5 / 5
# FAIRY TERN: 4 / 5
# FAN TAILED WIDOW: 2 / 5
# FASCIATED WREN: 4 / 5
# FIERY MINIVET: 5 / 5
# FIORDLAND PENGUIN: 4 / 5
# FIRE TAILLED MYZORNIS: 5 / 5
# FLAME BOWERBIRD: 5 / 5
# FLAME TANAGER: 5 / 5
# FRIGATE: 5 / 5
# GAMBELS QUAIL: 5 / 5
# GANG GANG COCKATOO: 5 / 5
# GILA WOODPECKER: 4 / 5
# GILDED FLICKER: 2 / 5
# GLOSSY IBIS: 5 / 5
# GO AWAY BIRD: 5 / 5
# GOLD WING WARBLER: 5 / 5
# GOLDEN BOWER BIRD: 5 / 5
# GOLDEN CHEEKED WARBLER: 5 / 5
# GOLDEN CHLOROPHONIA: 5 / 5
# GOLDEN EAGLE: 5 / 5
# GOLDEN PARAKEET: 5 / 5
# GOLDEN PHEASANT: 5 / 5
# GOLDEN PIPIT: 5 / 5
# GOULDIAN FINCH: 5 / 5
# GRANDALA: 4 / 5
# GRAY CATBIRD: 5 / 5
# GRAY KINGBIRD: 5 / 5
# GRAY PARTRIDGE: 5 / 5
# GREAT GRAY OWL: 5 / 5
# GREAT JACAMAR: 5 / 5
# GREAT KISKADEE: 5 / 5
# GREAT POTOO: 3 / 5
# GREAT TINAMOU: 5 / 5
# GREAT XENOPS: 5 / 5
# GREATER PEWEE: 5 / 5
# GREATOR SAGE GROUSE: 4 / 5
# GREEN BROADBILL: 5 / 5
# GREEN JAY: 5 / 5
# GREEN MAGPIE: 5 / 5
# GREY CUCKOOSHRIKE: 4 / 5
# GREY PLOVER: 4 / 5
# GROVED BILLED ANI: 5 / 5
# GUINEA TURACO: 5 / 5
# GUINEAFOWL: 5 / 5
# GURNEYS PITTA: 5 / 5
# GYRFALCON: 3 / 5
# HAMERKOP: 4 / 5
# HARLEQUIN DUCK: 5 / 5
# HARLEQUIN QUAIL: 5 / 5
# HARPY EAGLE: 5 / 5
# HAWAIIAN GOOSE: 5 / 5
# HAWFINCH: 5 / 5
# HELMET VANGA: 5 / 5
# HEPATIC TANAGER: 4 / 5
# HIMALAYAN BLUETAIL: 5 / 5
# HIMALAYAN MONAL: 5 / 5
# HOATZIN: 5 / 5
# HOODED MERGANSER: 4 / 5
# HOOPOES: 5 / 5
# HORNED GUAN: 4 / 5
# HORNED LARK: 5 / 5
# HORNED SUNGEM: 5 / 5
# HOUSE FINCH: 5 / 5
# HOUSE SPARROW: 5 / 5
# HYACINTH MACAW: 5 / 5
# IBERIAN MAGPIE: 5 / 5
# IBISBILL: 5 / 5
# IMPERIAL SHAQ: 3 / 5
# INCA TERN: 5 / 5
# INDIAN BUSTARD: 4 / 5
# INDIAN PITTA: 5 / 5
# INDIAN ROLLER: 5 / 5
# INDIAN VULTURE: 5 / 5
# INDIGO BUNTING: 5 / 5
# INDIGO FLYCATCHER: 5 / 5
# INLAND DOTTEREL: 5 / 5
# IVORY BILLED ARACARI: 5 / 5
# IVORY GULL: 5 / 5
# IWI: 5 / 5
# JABIRU: 5 / 5
# JACK SNIPE: 5 / 5
# JANDAYA PARAKEET: 5 / 5
# JAPANESE ROBIN: 5 / 5
# JAVA SPARROW: 5 / 5
# JOCOTOCO ANTPITTA: 5 / 5
# KAGU: 5 / 5
# KAKAPO: 5 / 5
# KILLDEAR: 5 / 5
# KING EIDER: 4 / 5
# KING VULTURE: 5 / 5
# KIWI: 5 / 5
# KOOKABURRA: 4 / 5
# LARK BUNTING: 5 / 5
# LAZULI BUNTING: 5 / 5
# LESSER ADJUTANT: 4 / 5
# LILAC ROLLER: 5 / 5
# LITTLE AUK: 5 / 5
# LOGGERHEAD SHRIKE: 2 / 5
# LONG-EARED OWL: 5 / 5
# MAGPIE GOOSE: 5 / 5
# MALABAR HORNBILL: 5 / 5
# MALACHITE KINGFISHER: 5 / 5
# MALAGASY WHITE EYE: 5 / 5
# MALEO: 5 / 5
# MALLARD DUCK: 4 / 5
# MANDRIN DUCK: 5 / 5
# MANGROVE CUCKOO: 4 / 5
# MARABOU STORK: 5 / 5
# MASKED BOOBY: 3 / 5
# MASKED LAPWING: 4 / 5
# MCKAYS BUNTING: 4 / 5
# MIKADO  PHEASANT: 5 / 5
# MOURNING DOVE: 4 / 5
# MYNA: 5 / 5
# NICOBAR PIGEON: 5 / 5
# NOISY FRIARBIRD: 4 / 5
# NORTHERN BEARDLESS TYRANNULET: 2 / 5
# NORTHERN CARDINAL: 5 / 5
# NORTHERN FLICKER: 5 / 5
# NORTHERN FULMAR: 4 / 5
# NORTHERN GANNET: 5 / 5
# NORTHERN GOSHAWK: 5 / 5
# NORTHERN JACANA: 5 / 5
# NORTHERN MOCKINGBIRD: 4 / 5
# NORTHERN PARULA: 5 / 5
# NORTHERN RED BISHOP: 5 / 5
# NORTHERN SHOVELER: 5 / 5
# OCELLATED TURKEY: 4 / 5
# OKINAWA RAIL: 5 / 5
# ORANGE BRESTED BUNTING: 5 / 5
# ORIENTAL BAY OWL: 5 / 5
# OSPREY: 2 / 5
# OSTRICH: 5 / 5
# OVENBIRD: 5 / 5
# OYSTER CATCHER: 5 / 5
# PAINTED BUNTING: 5 / 5
# PALILA: 5 / 5
# PARADISE TANAGER: 5 / 5
# PARAKETT  AKULET: 5 / 5
# PARUS MAJOR: 5 / 5
# PATAGONIAN SIERRA FINCH: 5 / 5
# PEACOCK: 4 / 5
# PEREGRINE FALCON: 5 / 5
# PHILIPPINE EAGLE: 4 / 5
# PINK ROBIN: 5 / 5
# POMARINE JAEGER: 4 / 5
# PUFFIN: 5 / 5
# PURPLE FINCH: 5 / 5
# PURPLE GALLINULE: 5 / 5
# PURPLE MARTIN: 5 / 5
# PURPLE SWAMPHEN: 5 / 5
# PYGMY KINGFISHER: 5 / 5
# QUETZAL: 5 / 5
# RAINBOW LORIKEET: 5 / 5
# RAZORBILL: 4 / 5
# RED BEARDED BEE EATER: 5 / 5
# RED BELLIED PITTA: 5 / 5
# RED BROWED FINCH: 4 / 5
# RED FACED CORMORANT: 5 / 5
# RED FACED WARBLER: 5 / 5
# RED FODY: 5 / 5
# RED HEADED DUCK: 5 / 5
# RED HEADED WOODPECKER: 5 / 5
# RED HONEY CREEPER: 5 / 5
# RED NAPED TROGON: 5 / 5
# RED TAILED HAWK: 4 / 5
# RED TAILED THRUSH: 5 / 5
# RED WINGED BLACKBIRD: 5 / 5
# RED WISKERED BULBUL: 5 / 5
# REGENT BOWERBIRD: 5 / 5
# RING-NECKED PHEASANT: 5 / 5
# ROADRUNNER: 5 / 5
# ROBIN: 4 / 5
# ROCK DOVE: 5 / 5
# ROSY FACED LOVEBIRD: 5 / 5
# ROUGH LEG BUZZARD: 5 / 5
# ROYAL FLYCATCHER: 5 / 5
# RUBY THROATED HUMMINGBIRD: 5 / 5
# RUDY KINGFISHER: 5 / 5
# RUFOUS KINGFISHER: 5 / 5
# RUFUOS MOTMOT: 5 / 5
# SAMATRAN THRUSH: 5 / 5
# SAND MARTIN: 4 / 5
# SANDHILL CRANE: 5 / 5
# SATYR TRAGOPAN: 5 / 5
# SCARLET CROWNED FRUIT DOVE: 4 / 5
# SCARLET IBIS: 5 / 5
# SCARLET MACAW: 5 / 5
# SCARLET TANAGER: 5 / 5
# SHOEBILL: 5 / 5
# SHORT BILLED DOWITCHER: 4 / 5
# SKUA: 0 / 5
# SMITHS LONGSPUR: 5 / 5
# SNOWY EGRET: 5 / 5
# SNOWY OWL: 5 / 5
# SNOWY PLOVER: 3 / 5
# SORA: 5 / 5
# SPANGLED COTINGA: 5 / 5
# SPLENDID WREN: 5 / 5
# SPOON BILED SANDPIPER: 5 / 5
# SPOONBILL: 5 / 5
# SPOTTED CATBIRD: 5 / 5
# SRI LANKA BLUE MAGPIE: 5 / 5
# STEAMER DUCK: 5 / 5
# STORK BILLED KINGFISHER: 5 / 5
# STRAWBERRY FINCH: 2 / 5
# STRIPED OWL: 5 / 5
# STRIPPED MANAKIN: 5 / 5
# STRIPPED SWALLOW: 5 / 5
# SUPERB STARLING: 5 / 5
# SWINHOES PHEASANT: 5 / 5
# TAILORBIRD: 5 / 5
# TAIWAN MAGPIE: 5 / 5
# TAKAHE: 5 / 5
# TASMANIAN HEN: 5 / 5
# TEAL DUCK: 5 / 5
# TIT MOUSE: 5 / 5
# TOUCHAN: 5 / 5
# TOWNSENDS WARBLER: 4 / 5
# TREE SWALLOW: 5 / 5
# TRICOLORED BLACKBIRD: 1 / 5
# TROPICAL KINGBIRD: 5 / 5
# TRUMPTER SWAN: 5 / 5
# TURKEY VULTURE: 5 / 5
# TURQUOISE MOTMOT: 5 / 5
# UMBRELLA BIRD: 4 / 5
# VARIED THRUSH: 5 / 5
# VEERY: 4 / 5
# VENEZUELIAN TROUPIAL: 4 / 5
# VERMILION FLYCATHER: 4 / 5
# VICTORIA CROWNED PIGEON: 5 / 5
# VIOLET GREEN SWALLOW: 5 / 5
# VIOLET TURACO: 5 / 5
# VULTURINE GUINEAFOWL: 5 / 5
# WALL CREAPER: 5 / 5
# WATTLED CURASSOW: 5 / 5
# WATTLED LAPWING: 4 / 5
# WHIMBREL: 5 / 5
# WHITE BROWED CRAKE: 5 / 5
# WHITE CHEEKED TURACO: 4 / 5
# WHITE CRESTED HORNBILL: 4 / 5
# WHITE NECKED RAVEN: 3 / 5
# WHITE TAILED TROPIC: 4 / 5
# WHITE THROATED BEE EATER: 5 / 5
# WILD TURKEY: 5 / 5
# WILSONS BIRD OF PARADISE: 5 / 5
# WOOD DUCK: 5 / 5
# YELLOW BELLIED FLOWERPECKER: 5 / 5
# YELLOW CACIQUE: 5 / 5
# YELLOW HEADED BLACKBIRD: 4 / 5
